# %% [markdown]
# <a href="https://colab.research.google.com/github/bodyelhandi2024-creator/Titanic/blob/main/word_teacher%F0%9F%A7%90%F0%9F%8C%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m textblob.download_corpora

# %%
from textblob import Word

# %%
print("Hello, I'am the word teacher (～￣▽￣)～")
print("type ONE word, and I will aalyze it with NLP")
print("📂......📄........📄......📄........📄......📄......📁")
while True:
  user_word = input("/nEnter a word (or 'quit' to stop): ").lower()
  if user_word == 'quit':
    print("Bye! 😁")
    break

  w = Word(user_word)

  corrected = w.spellcheck()[0][0]

  lemma = Word(corrected).lemmatize('v')

  print(f"\n🔎or NLP Analysis f '{user_word}':")
  print(f"✅ Corrected spelling: {corrected}")
  print(f"🌱 Lemma (base form): {lemma}")
  print("📂......📄........📄......📄........📄......📄......📁")
# Out:
# Hello, I'am the word teacher (～￣▽￣)～
# type ONE word, and I will aalyze it with NLP
# 📂......📄........📄......📄........📄......📄......📁
# /nEnter a word (or 'quit' to stop): running
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3129352588.py in <cell line: 0>()
#       8     break
#       9
# ---> 10   w = Word(user_word)
#      11
#      12   corrected = w.spellcheck()[0][0]
#
# NameError: name 'Word' is not defined
